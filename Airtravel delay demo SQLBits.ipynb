# %% [markdown]
# # Predict airtravel delay
#
# ## Load data

# %%
df = spark.sql("SELECT DayOfWeek, DepTime, AirTime, CASE WHEN (ArrDelay < 60) THEN 0 ELSE 1 END AS DelayType FROM demodata.flightdelay")
df.count()
# Out:
# StatementMeta(, 4797ad00-b78c-4ff3-9bf9-e026ac033a53, 4, Finished, Available)
# 484551

# %%
display(df.head(15))
# Out:
# StatementMeta(, 4797ad00-b78c-4ff3-9bf9-e026ac033a53, 5, Finished, Available)
# SynapseWidget(Synapse.DataFrame, 25672267-38c7-483d-8535-71cb6de4d82d)

# %%
from pyspark import ml as sparkml
print(dir(sparkml))
# Out:
# StatementMeta(, 4797ad00-b78c-4ff3-9bf9-e026ac033a53, 6, Finished, Available)
# ['Estimator', 'Model', 'Pipeline', 'PipelineModel', 'PredictionModel', 'Predictor', 'TorchDistributor', 'Transformer', 'UnaryTransformer', '__all__', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__path__', '__spec__', 'base', 'classification', 'clustering', 'common', 'evaluation', 'feature', 'fpm', 'image', 'linalg', 'param', 'pipeline', 'recommendation', 'regression', 'stat', 'torch', 'tree', 'tuning', 'util', 'wrapper']

# %% [markdown]
# ## Determine features and label

# %%
print(df.columns)
featureslist = df.columns[:-1]
print(featureslist)
label = df.columns[-1]
print(label)
# Out:
# StatementMeta(, 4797ad00-b78c-4ff3-9bf9-e026ac033a53, 7, Finished, Available)
# ['DayOfWeek', 'DepTime', 'AirTime', 'DelayType']
# ['DayOfWeek', 'DepTime', 'AirTime']
# DelayType

# %%
# VectorAssembler builds a 2 column dataset: features and labels
from pyspark.ml.feature import VectorAssembler
myVA = VectorAssembler(inputCols=featureslist, outputCol="features")
display(myVA.transform(df).head(15))
# Out:
# StatementMeta(, 4797ad00-b78c-4ff3-9bf9-e026ac033a53, 8, Finished, Available)
# SynapseWidget(Synapse.DataFrame, 194a3eb8-1b40-4eec-b1e2-bd70c9801355)

# %% [markdown]
# ## Pick a machine learning algorithm

# %%
print(dir(sparkml.classification))
# Out:
# StatementMeta(, 4797ad00-b78c-4ff3-9bf9-e026ac033a53, 9, Finished, Available)
# ['ABCMeta', 'Any', 'ArrayType', 'BinaryLogisticRegressionSummary', 'BinaryLogisticRegressionTrainingSummary', 'BinaryRandomForestClassificationSummary', 'BinaryRandomForestClassificationTrainingSummary', 'CM', 'ClassificationModel', 'Classifier', 'DataFrame', 'DecisionTreeClassificationModel', 'DecisionTreeClassifier', 'DecisionTreeRegressionModel', 'DefaultParamsReader', 'DefaultParamsWriter', 'Dict', 'DoubleType', 'Estimator', 'FMClassificationModel', 'FMClassificationSummary', 'FMClassificationTrainingSummary', 'FMClassifier', 'GBTClassificationModel', 'GBTClassifier', 'Generic', 'HasAggregationDepth', 'HasBlockSize', 'HasElasticNetParam', 'HasFitIntercept', 'HasMaxBlockSizeInMB', 'HasMaxIter', 'HasParallelism', 'HasProbabilityCol', 'HasRawPredictionCol', 'HasRegParam', 'HasSeed', 'HasSolver', 'HasStandardization', 'HasStepSize', 'HasThreshold', 'HasThresholds', 'HasTol', 'HasTrainingSummary', 'HasWeightCol', 'Iterable', 'JPM', 'JavaMLReadable', 'JavaMLReader', 'JavaMLWritable', 'JavaMLWriter', 'JavaParams', 'JavaPredictionModel', 'JavaPredictor', 'JavaWrapper', 'LinearSVC', 'LinearSVCModel', 'LinearSVCSummary', 'LinearSVCTrainingSummary', 'List', 'LogisticRegression', 'LogisticRegressionModel', 'LogisticRegressionSummary', 'LogisticRegressionTrainingSummary', 'MLReadable', 'MLReader', 'MLWritable', 'MLWriter', 'Matrix', 'Model', 'MultilayerPerceptronClassificationModel', 'MultilayerPerceptronClassificationSummary', 'MultilayerPerceptronClassificationTrainingSummary', 'MultilayerPerceptronClassifier', 'NaiveBayes', 'NaiveBayesModel', 'OneVsRest', 'OneVsRestModel', 'OneVsRestModelReader', 'OneVsRestModelWriter', 'OneVsRestReader', 'OneVsRestWriter', 'Optional', 'Param', 'Params', 'PredictionModel', 'Predictor', 'ProbabilisticClassificationModel', 'ProbabilisticClassifier', 'RandomForestClassificationModel', 'RandomForestClassificationSummary', 'RandomForestClassificationTrainingSummary', 'RandomForestClassifier', 'Row', 'SparkContext', 'StorageLevel', 'T', 'TYPE_CHECKING', 'ThreadPool', 'Type', 'TypeConverters', 'TypeVar', 'Union', 'Vector', 'VectorUDT', 'Vectors', '_BinaryClassificationSummary', '_ClassificationSummary', '_ClassifierParams', '_DecisionTreeClassifierParams', '_DecisionTreeModel', '_DecisionTreeParams', '_FactorizationMachinesParams', '_GBTClassifierParams', '_GBTParams', '_HasVarianceImpurity', '_JavaClassificationModel', '_JavaClassifier', '_JavaProbabilisticClassificationModel', '_JavaProbabilisticClassifier', '_LinearSVCParams', '_LogisticRegressionParams', '_MultilayerPerceptronParams', '_NaiveBayesParams', '_OneVsRestParams', '_OneVsRestSharedReadWrite', '_PredictorParams', '_ProbabilisticClassifierParams', '_RandomForestClassifierParams', '_RandomForestParams', '_TrainingSummary', '_TreeClassifierParams', '_TreeEnsembleModel', '__all__', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', 'abstractmethod', 'cast', 'inherit_doc', 'inheritable_thread_target', 'keyword_only', 'operator', 'os', 'overload', 'since', 'sys', 'udf', 'uuid', 'warnings', 'when']

# %%
from pyspark.ml.classification import DecisionTreeClassifier
dtc = DecisionTreeClassifier(featuresCol="features", labelCol=label)
print(dtc.explainParams())
# Out:
# StatementMeta(, 4797ad00-b78c-4ff3-9bf9-e026ac033a53, 10, Finished, Available)
# cacheNodeIds: If false, the algorithm will pass trees to executors to match instances with nodes. If true, the algorithm will cache node IDs for each instance. Caching can speed up training of deeper trees. Users can set how often should the cache be checkpointed or disable it by setting checkpointInterval. (default: False)
# checkpointInterval: set checkpoint interval (>= 1) or disable checkpoint (-1). E.g. 10 means that the cache will get checkpointed every 10 iterations. Note: this setting will be ignored if the checkpoint directory is not set in the SparkContext. (default: 10)
# featuresCol: features column name. (default: features, current: features)
# impurity: Criterion used for information gain calculation (case-insensitive). Supported options: entropy, gini (default: gini)
# labelCol: label column name. (default: label, current: DelayType)
# leafCol: Leaf indices column name. Predicted leaf index of each instance in each tree by preorder. (default: )
# maxBins: Max number of bins for discretizing continuous features.  Must be >=2 and >= number of categories for any categorical feature. (default: 32)
# maxDepth: Maximum depth of the tree. (>= 0) E.g., depth 0 means 1 leaf node; depth 1 means 1 internal node + 2 leaf nodes. Must be in range [0, 30]. (default: 5)
# maxMemoryInMB: Maximum memory in MB allocated to histogram aggregation. If too small, then 1 node will be split per iteration, and its aggregates may exceed this size. (default: 256)
# minInfoGain: Minimum information gain for a split to be considered at a tree node. (default: 0.0)
# minInstancesPerNode: Minimum number of instances each child must have after split. If a split causes the left or right child to have fewer than minInstancesPerNode, the split will be discarded as invalid. Should be >= 1. (default: 1)
# minWeightFractionPerNode: Minimum fraction of the weighted sample count that each child must have after split. If a split causes the fraction of the total weight in the left or right child to be less than minWeightFractionPerNode, the split will be discarded as invalid. Should be in interval [0.0, 0.5). (default: 0.0)
# predictionCol: prediction column name. (default: prediction)
# probabilityCol: Column name for predicted class conditional probabilities. Note: Not all models output well-calibrated probability estimates! These probabilities should be treated as confidences, not precise probabilities. (default: probability)
# rawPredictionCol: raw prediction (a.k.a. confidence) column name. (default: rawPrediction)
# seed: random seed. (default: 956191873026065186)
# thresholds: Thresholds in multi-class classification to adjust the probability of predicting each class. Array must have length equal to the number of classes, with values > 0, excepting that at most one value may be 0. The class with largest value p/t is predicted, where p is the original probability of that class and t is the class's threshold. (undefined)
# weightCol: weight column name. If this is not set or empty, we treat all instance weights as 1.0. (undefined)

# %% [markdown]
# ## Let's build a pipeline

# %%
from pyspark.ml import Pipeline, Estimator
sqlbitspipeline = Pipeline(stages=[myVA,dtc])
print(isinstance(sqlbitspipeline, Estimator))
print(dir(sqlbitspipeline))
# Out:
# StatementMeta(, 4797ad00-b78c-4ff3-9bf9-e026ac033a53, 11, Finished, Available)
# True
# ['__abstractmethods__', '__annotations__', '__class__', '__class_getitem__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__orig_bases__', '__parameters__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__slots__', '__str__', '__subclasshook__', '__weakref__', '_abc_impl', '_copyValues', '_copy_params', '_defaultParamMap', '_dummy', '_fit', '_from_java', '_gorilla_active_patch_fit', '_gorilla_original_fit', '_input_kwargs', '_is_protocol', '_paramMap', '_params', '_randomUID', '_resetUid', '_resolveParam', '_set', '_setDefault', '_shouldOwn', '_testOwnParam', '_to_java', 'clear', 'copy', 'explainParam', 'explainParams', 'extractParamMap', 'fit', 'fitMultiple', 'getOrDefault', 'getParam', 'getStages', 'hasDefault', 'hasParam', 'isDefined', 'isSet', 'load', 'params', 'read', 'save', 'set', 'setParams', 'setStages', 'stages', 'uid', 'write']

# %% [markdown]
# ## Split training and test data set

# %%
train, test = df.randomSplit([0.7,0.3])
print('training set size',train.count())
print('test set size',test.count())
# Out:
# StatementMeta(, 4797ad00-b78c-4ff3-9bf9-e026ac033a53, 12, Finished, Available)
# training set size 339635
# test set size 144916

# %% [markdown]
# ## Run, pipeline, run!

# %%
predictor = sqlbitspipeline.fit(train)
predictions = predictor.transform(test)
# Out:
# StatementMeta(, 4797ad00-b78c-4ff3-9bf9-e026ac033a53, 13, Finished, Available)
# 2024-03-21:07:49:33,760 WARNING  [tracking_store.py:153] log_inputs not supported

# %%
print(predictor.stages[1].toDebugString)
# Out:
# StatementMeta(, 4797ad00-b78c-4ff3-9bf9-e026ac033a53, 14, Finished, Available)
# DecisionTreeClassificationModel: uid=DecisionTreeClassifier_c2be9eaf191b, depth=5, numNodes=21, numClasses=2, numFeatures=3
#   If (feature 1 <= 2220.5)
#    Predict: 0.0
#   Else (feature 1 > 2220.5)
#    If (feature 2 <= 206.5)
#     If (feature 1 <= 2314.5)
#      Predict: 1.0
#     Else (feature 1 > 2314.5)
#      If (feature 2 <= 47.5)
#       Predict: 1.0
#      Else (feature 2 > 47.5)
#       If (feature 2 <= 184.5)
#        Predict: 1.0
#       Else (feature 2 > 184.5)
#        Predict: 0.0
#    Else (feature 2 > 206.5)
#     If (feature 2 <= 324.5)
#      If (feature 2 <= 232.5)
#       If (feature 1 <= 2314.5)
#        Predict: 1.0
#       Else (feature 1 > 2314.5)
#        Predict: 0.0
#      Else (feature 2 > 232.5)
#       Predict: 0.0
#     Else (feature 2 > 324.5)
#      If (feature 0 <= 5.5)
#       Predict: 1.0
#      Else (feature 0 > 5.5)
#       If (feature 0 <= 6.5)
#        Predict: 0.0
#       Else (feature 0 > 6.5)
#        Predict: 1.0

# %%
display(predictions.head(15))
# Out:
# StatementMeta(, 4797ad00-b78c-4ff3-9bf9-e026ac033a53, 15, Finished, Available)
# SynapseWidget(Synapse.DataFrame, 85b48245-3eed-4112-94f5-53bb67067dd5)

# %% [markdown]
# ## Let's evaluate the quality

# %%
from pyspark.ml.evaluation import BinaryClassificationEvaluator
eval = BinaryClassificationEvaluator(labelCol='DelayType', rawPredictionCol='prediction')
eval.evaluate(predictions)
# Out:
# StatementMeta(, 4797ad00-b78c-4ff3-9bf9-e026ac033a53, 16, Finished, Available)
# 2024-03-21:07:50:15,310 WARNING  [tracking_store.py:153] log_inputs not supported
# 0.5284200050049226

# %%
from sklearn.metrics import classification_report, confusion_matrix

y_true = predictions.select(['DelayType']).collect()
y_pred = predictions.select(['prediction']).collect()
print(classification_report(y_true, y_pred))
print(confusion_matrix(y_true,y_pred))
# Out:
# StatementMeta(, 4797ad00-b78c-4ff3-9bf9-e026ac033a53, 17, Finished, Available)
#               precision    recall  f1-score   support
#
#            0       0.67      0.98      0.79     94702
#            1       0.69      0.07      0.13     50214
#
#     accuracy                           0.67    144916
#    macro avg       0.68      0.53      0.46    144916
# weighted avg       0.68      0.67      0.57    144916
#
# [[93037  1665]
#  [46477  3737]]

# %% [markdown]
# ## Back to the drawing board
#
# 1. More features
# 1. Hyperparameterization
# 1. More ML algorithms
#
# ## FLAML to the recue!

# %%
from flaml import AutoML
automl = AutoML()

automl_settings = {
    "time_budget": 100,  # in seconds
    "metric": 'accuracy',
    "task": 'classification',
    "log_file_name": "flightdelay.log",
}

pandastrain = train.toPandas()
automl.fit(X_train=pandastrain[featureslist], y_train=pandastrain[label],
           **automl_settings)
# Out:
# StatementMeta(, 4797ad00-b78c-4ff3-9bf9-e026ac033a53, 18, Finished, Available)
# [flaml.automl.logger: 03-21 07:51:05] {1750} INFO - task = classification
# [flaml.automl.logger: 03-21 07:51:05] {1761} INFO - Evaluation method: holdout
# [flaml.automl.logger: 03-21 07:51:05] {1859} INFO - Minimizing error metric: 1-accuracy
# [flaml.automl.logger: 03-21 07:51:07] {1977} INFO - List of ML learners in AutoML Run: ['lgbm', 'rf', 'xgboost', 'extra_tree', 'xgb_limitdepth', 'sgd', 'catboost', 'lrl1']
# [flaml.automl.logger: 03-21 07:51:07] {2272} INFO - iteration 0, current learner lgbm
# [flaml.automl.logger: 03-21 07:51:07] {2401} INFO - Estimated sufficient time budget=134545s. Estimated necessary time budget=3317s.
# 2024/03/21 07:51:29 WARNING mlflow.utils.requirements_utils: The following packages were not found in the public PyPI package index as of 2023-08-15; if these packages are not present in the public PyPI index, you must install them manually before loading your model: {'synapseml-mlflow', 'synapseml-internal'}
# [flaml.automl.logger: 03-21 07:51:30] {2450} INFO -  at 2.9s,	estimator lgbm's best error=0.3429,	best estimator lgbm's best error=0.3429
# [flaml.automl.logger: 03-21 07:51:30] {2272} INFO - iteration 1, current learner lgbm
# 2024/03/21 07:51:47 WARNING mlflow.utils.requirements_utils: The following packages were not found in the public PyPI package index as of 2023-08-15; if these packages are not present in the public PyPI index, you must install them manually before loading your model: {'synapseml-mlflow', 'synapseml-internal'}
# [flaml.automl.logger: 03-21 07:51:49] {2450} INFO -  at 25.7s,	estimator lgbm's best error=0.3429,	best estimator lgbm's best error=0.3429
# [flaml.automl.logger: 03-21 07:51:49] {2272} INFO - iteration 2, current learner lgbm
# 2024/03/21 07:52:06 WARNING mlflow.utils.requirements_utils: The following packages were not found in the public PyPI package index as of 2023-08-15; if these packages are not present in the public PyPI index, you must install them manually before loading your model: {'synapseml-mlflow', 'synapseml-internal'}
# [flaml.automl.logger: 03-21 07:52:07] {2450} INFO -  at 44.2s,	estimator lgbm's best error=0.3255,	best estimator lgbm's best error=0.3255
# [flaml.automl.logger: 03-21 07:52:07] {2272} INFO - iteration 3, current learner lgbm
# 2024/03/21 07:52:24 WARNING mlflow.utils.requirements_utils: The following packages were not found in the public PyPI package index as of 2023-08-15; if these packages are not present in the public PyPI index, you must install them manually before loading your model: {'synapseml-mlflow', 'synapseml-internal'}
# [flaml.automl.logger: 03-21 07:52:25] {2450} INFO -  at 62.9s,	estimator lgbm's best error=0.3234,	best estimator lgbm's best error=0.3234
# [flaml.automl.logger: 03-21 07:52:25] {2272} INFO - iteration 4, current learner lgbm
# 2024/03/21 07:52:42 WARNING mlflow.utils.requirements_utils: The following packages were not found in the public PyPI package index as of 2023-08-15; if these packages are not present in the public PyPI index, you must install them manually before loading your model: {'synapseml-mlflow', 'synapseml-internal'}
# [flaml.automl.logger: 03-21 07:52:44] {2450} INFO -  at 80.9s,	estimator lgbm's best error=0.3234,	best estimator lgbm's best error=0.3234
# [flaml.automl.logger: 03-21 07:52:44] {2272} INFO - iteration 5, current learner lgbm
# 2024/03/21 07:53:00 WARNING mlflow.utils.requirements_utils: The following packages were not found in the public PyPI package index as of 2023-08-15; if these packages are not present in the public PyPI index, you must install them manually before loading your model: {'synapseml-mlflow', 'synapseml-internal'}
# [flaml.automl.logger: 03-21 07:53:02] {2450} INFO -  at 99.2s,	estimator lgbm's best error=0.3230,	best estimator lgbm's best error=0.3230
# [flaml.automl.logger: 03-21 07:53:02] {2693} INFO - retrain lgbm for 0.2s
# [flaml.automl.logger: 03-21 07:53:02] {2696} INFO - retrained model: LGBMClassifier(colsample_bytree=0.8304072431299575,
#                learning_rate=0.7590459488450938, max_bin=255,
#                min_child_samples=5, n_estimators=1, n_jobs=-1, num_leaves=5,
#                reg_alpha=0.0019513780315197576, reg_lambda=0.04792552866398477,
#                verbose=-1)
# [flaml.automl.logger: 03-21 07:53:02] {2697} INFO - Auto Feature Engineering pipeline: None
# [flaml.automl.logger: 03-21 07:53:02] {2699} INFO - Best MLflow run name:
# [flaml.automl.logger: 03-21 07:53:02] {2700} INFO - Best MLflow run id: 8fd4103e-db3c-43ee-a60f-72cbf1c4dd06
# [flaml.automl.logger: 03-21 07:53:02] {2007} INFO - fit succeeded
# [flaml.automl.logger: 03-21 07:53:02] {2008} INFO - Time taken to find the best model: 99.20190048217773

# %%
print(automl.model.estimator)
# Out:
# StatementMeta(, 4797ad00-b78c-4ff3-9bf9-e026ac033a53, 19, Finished, Available)
# LGBMClassifier(colsample_bytree=0.8304072431299575,
#                learning_rate=0.7590459488450938, max_bin=255,
#                min_child_samples=5, n_estimators=1, n_jobs=-1, num_leaves=5,
#                reg_alpha=0.0019513780315197576, reg_lambda=0.04792552866398477,
#                verbose=-1)

# %%
print(dir(automl))
# Out:
# StatementMeta(, 4797ad00-b78c-4ff3-9bf9-e026ac033a53, 20, Finished, Available)
# ['__class__', '__del__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__setstate__', '__sizeof__', '__sklearn_clone__', '__str__', '__subclasshook__', '__version__', '__weakref__', '_active_estimators', '_auto_augment', '_best_estimator', '_best_iteration', '_build_request_for_signature', '_check_feature_names', '_check_n_features', '_config_history', '_decide_eval_method', '_df', '_early_stop', '_eci', '_ensemble', '_estimator_index', '_estimator_type', '_feature_names_in_', '_featurization', '_force_cancel', '_fullsize_reached', '_get_default_requests', '_get_metadata_request', '_get_param_names', '_get_tags', '_hpo_method', '_iter_per_learner', '_iter_per_learner_fullsize', '_label_transformer', '_learner_selector', '_log_trial', '_log_type', '_max_iter', '_max_iter_per_learner', '_mem_thres', '_metric_constraints', '_min_sample_size', '_min_sample_size_input', '_mlflow_exp_name', '_mlflow_logging', '_more_tags', '_n_concurrent_trials', '_ndim', '_nrow', '_pred_time_limit', '_prepare_data', '_random', '_repr_html_', '_repr_html_inner', '_repr_mimebundle_', '_retrain_in_budget', '_retrained_config', '_sample', '_search', '_search_parallel', '_search_sequential', '_search_states', '_seed', '_select_estimator', '_selected', '_settings', '_skip_transform', '_split_type', '_start_time_flag', '_state', '_time_taken_best_iter', '_track_iter', '_trained_estimator', '_training_log', '_transformer', '_use_ray', '_use_spark', '_validate_data', '_validate_params', '_warn_threshold', 'add_learner', 'autolog_extra_tag', 'automl_pipeline', 'best_config', 'best_config_per_estimator', 'best_config_train_time', 'best_estimator', 'best_iteration', 'best_loss', 'best_loss_per_estimator', 'best_model_for_estimator', 'best_result', 'best_run_id', 'best_run_name', 'cat_hp_cost', 'classes_', 'config_history', 'data_size_full', 'estimator_list', 'feature_importances_', 'feature_names_in_', 'feature_transformer', 'fit', 'get_estimator_from_log', 'get_metadata_routing', 'get_params', 'label_transformer', 'low_cost_partial_config', 'max_resource', 'metric_constraints', 'metrics_for_best_config', 'min_resource', 'mlflow_integration', 'model', 'modelcount', 'n_features_in_', 'pickle', 'points_to_evaluate', 'predict', 'predict_proba', 'preserve_checkpoint', 'resource_attr', 'retrain_from_log', 'save_best_config', 'score', 'search_space', 'set_fit_request', 'set_params', 'split_ratio', 'time_to_find_best_model', 'trainable', 'verbose']

# %%
testPandas = test.toPandas()
prediction_arr = automl.predict(testPandas[featureslist])
predictions = testPandas
predictions['prediction'] = prediction_arr
display(predictions)
# Out:
# StatementMeta(, 4797ad00-b78c-4ff3-9bf9-e026ac033a53, 27, Finished, Available)
# SynapseWidget(Synapse.DataFrame, e950395e-3d5e-4f6c-a2ee-ead2ce5d210a)

# %%
y_true = predictions['DelayType']
y_pred = predictions['prediction']
print(classification_report(y_true, y_pred))
print(confusion_matrix(y_true,y_pred))
# Out:
# StatementMeta(, 4797ad00-b78c-4ff3-9bf9-e026ac033a53, 28, Finished, Available)
#               precision    recall  f1-score   support
#
#            0       0.67      0.97      0.80     94702
#            1       0.69      0.11      0.19     50214
#
#     accuracy                           0.67    144916
#    macro avg       0.68      0.54      0.50    144916
# weighted avg       0.68      0.67      0.59    144916
#
# [[92083  2619]
#  [44507  5707]]

# %% [markdown]
# ## Add more features

# %%
df = spark.sql("SELECT DayOfWeek, DepTime, AirTime, UniqueCarrier, Origin, Dest, CASE WHEN (ArrDelay < 60) THEN 0 ELSE 1 END AS DelayType FROM demodata.flightdelay")
automl_settings = {
    "time_budget": 500,  # in seconds
    "metric": 'accuracy',
    "task": 'classification',
    "log_file_name": "flightdelay.log",
}
train, test = df.randomSplit([0.7,0.3])
pandastrain = train.toPandas()
featureslist = df.columns[:-1]
automl.fit(X_train=pandastrain[featureslist], y_train=pandastrain[label],
           **automl_settings)
# Out:
# StatementMeta(, 4797ad00-b78c-4ff3-9bf9-e026ac033a53, 30, Finished, Available)
# [flaml.automl.logger: 03-21 08:12:12] {1750} INFO - task = classification
# [flaml.automl.logger: 03-21 08:12:12] {1761} INFO - Evaluation method: holdout
# [flaml.automl.logger: 03-21 08:12:12] {1859} INFO - Minimizing error metric: 1-accuracy
# [flaml.automl.logger: 03-21 08:12:12] {1977} INFO - List of ML learners in AutoML Run: ['lgbm', 'rf', 'xgboost', 'extra_tree', 'xgb_limitdepth', 'sgd', 'catboost', 'lrl1']
# [flaml.automl.logger: 03-21 08:12:12] {2272} INFO - iteration 0, current learner lgbm
# [flaml.automl.logger: 03-21 08:12:12] {2401} INFO - Estimated sufficient time budget=12199s. Estimated necessary time budget=301s.
# [flaml.automl.logger: 03-21 08:12:12] {2450} INFO -  at 0.8s,	estimator lgbm's best error=0.3451,	best estimator lgbm's best error=0.3451
# [flaml.automl.logger: 03-21 08:12:12] {2272} INFO - iteration 1, current learner lgbm
# [flaml.automl.logger: 03-21 08:12:12] {2450} INFO -  at 0.8s,	estimator lgbm's best error=0.3451,	best estimator lgbm's best error=0.3451
# [flaml.automl.logger: 03-21 08:12:12] {2272} INFO - iteration 2, current learner lgbm
# [flaml.automl.logger: 03-21 08:12:12] {2450} INFO -  at 0.8s,	estimator lgbm's best error=0.3340,	best estimator lgbm's best error=0.3340
# [flaml.automl.logger: 03-21 08:12:12] {2272} INFO - iteration 3, current learner sgd
# No low-cost partial config given to the search algorithm. For cost-frugal search, consider providing low-cost values for cost-related hps via 'low_cost_partial_config'. More info can be found at https://microsoft.github.io/FLAML/docs/FAQ#about-low_cost_partial_config-in-tune
# [flaml.automl.logger: 03-21 08:12:12] {2450} INFO -  at 0.9s,	estimator sgd's best error=0.3451,	best estimator lgbm's best error=0.3340
# [flaml.automl.logger: 03-21 08:12:12] {2272} INFO - iteration 4, current learner lgbm
# [flaml.automl.logger: 03-21 08:12:12] {2450} INFO -  at 1.0s,	estimator lgbm's best error=0.3228,	best estimator lgbm's best error=0.3228
# [flaml.automl.logger: 03-21 08:12:12] {2272} INFO - iteration 5, current learner lgbm
# [flaml.automl.logger: 03-21 08:12:12] {2450} INFO -  at 1.1s,	estimator lgbm's best error=0.3228,	best estimator lgbm's best error=0.3228
# [flaml.automl.logger: 03-21 08:12:12] {2272} INFO - iteration 6, current learner xgboost
# [flaml.automl.logger: 03-21 08:12:13] {2450} INFO -  at 1.3s,	estimator xgboost's best error=0.3313,	best estimator lgbm's best error=0.3228
# [flaml.automl.logger: 03-21 08:12:13] {2272} INFO - iteration 7, current learner extra_tree
# [flaml.automl.logger: 03-21 08:12:13] {2450} INFO -  at 1.5s,	estimator extra_tree's best error=0.3451,	best estimator lgbm's best error=0.3228
# [flaml.automl.logger: 03-21 08:12:13] {2272} INFO - iteration 8, current learner rf
# [flaml.automl.logger: 03-21 08:12:13] {2450} INFO -  at 1.5s,	estimator rf's best error=0.3362,	best estimator lgbm's best error=0.3228
# [flaml.automl.logger: 03-21 08:12:13] {2272} INFO - iteration 9, current learner lgbm
# [flaml.automl.logger: 03-21 08:12:13] {2450} INFO -  at 1.6s,	estimator lgbm's best error=0.3221,	best estimator lgbm's best error=0.3221
# [flaml.automl.logger: 03-21 08:12:13] {2272} INFO - iteration 10, current learner lgbm
# [flaml.automl.logger: 03-21 08:12:13] {2450} INFO -  at 1.6s,	estimator lgbm's best error=0.3221,	best estimator lgbm's best error=0.3221
# [flaml.automl.logger: 03-21 08:12:13] {2272} INFO - iteration 11, current learner rf
# [flaml.automl.logger: 03-21 08:12:13] {2450} INFO -  at 1.7s,	estimator rf's best error=0.3273,	best estimator lgbm's best error=0.3221
# [flaml.automl.logger: 03-21 08:12:13] {2272} INFO - iteration 12, current learner rf
# [flaml.automl.logger: 03-21 08:12:13] {2450} INFO -  at 1.8s,	estimator rf's best error=0.3273,	best estimator lgbm's best error=0.3221
# [flaml.automl.logger: 03-21 08:12:13] {2272} INFO - iteration 13, current learner xgboost
# [flaml.automl.logger: 03-21 08:12:13] {2450} INFO -  at 1.8s,	estimator xgboost's best error=0.3313,	best estimator lgbm's best error=0.3221
# [flaml.automl.logger: 03-21 08:12:13] {2272} INFO - iteration 14, current learner extra_tree
# [flaml.automl.logger: 03-21 08:12:13] {2450} INFO -  at 1.9s,	estimator extra_tree's best error=0.3433,	best estimator lgbm's best error=0.3221
# [flaml.automl.logger: 03-21 08:12:13] {2272} INFO - iteration 15, current learner rf
# [flaml.automl.logger: 03-21 08:12:13] {2450} INFO -  at 2.1s,	estimator rf's best error=0.3273,	best estimator lgbm's best error=0.3221
# [flaml.automl.logger: 03-21 08:12:13] {2272} INFO - iteration 16, current learner sgd
# [flaml.automl.logger: 03-21 08:12:13] {2450} INFO -  at 2.1s,	estimator sgd's best error=0.3451,	best estimator lgbm's best error=0.3221
# [flaml.automl.logger: 03-21 08:12:13] {2272} INFO - iteration 17, current learner lgbm
# [flaml.automl.logger: 03-21 08:12:13] {2450} INFO -  at 2.1s,	estimator lgbm's best error=0.3221,	best estimator lgbm's best error=0.3221
# [flaml.automl.logger: 03-21 08:12:13] {2272} INFO - iteration 18, current learner sgd
# [flaml.automl.logger: 03-21 08:12:13] {2450} INFO -  at 2.2s,	estimator sgd's best error=0.3427,	best estimator lgbm's best error=0.3221
# [flaml.automl.logger: 03-21 08:12:13] {2272} INFO - iteration 19, current learner lgbm
# [flaml.automl.logger: 03-21 08:12:14] {2450} INFO -  at 2.2s,	estimator lgbm's best error=0.3179,	best estimator lgbm's best error=0.3179
# [flaml.automl.logger: 03-21 08:12:14] {2272} INFO - iteration 20, current learner xgboost
# [flaml.automl.logger: 03-21 08:12:14] {2450} INFO -  at 2.3s,	estimator xgboost's best error=0.3289,	best estimator lgbm's best error=0.3179
# [flaml.automl.logger: 03-21 08:12:14] {2272} INFO - iteration 21, current learner lgbm
# [flaml.automl.logger: 03-21 08:12:14] {2450} INFO -  at 2.4s,	estimator lgbm's best error=0.3179,	best estimator lgbm's best error=0.3179
# [flaml.automl.logger: 03-21 08:12:14] {2272} INFO - iteration 22, current learner lgbm
# [flaml.automl.logger: 03-21 08:12:14] {2450} INFO -  at 3.0s,	estimator lgbm's best error=0.3179,	best estimator lgbm's best error=0.3179
# [flaml.automl.logger: 03-21 08:12:14] {2272} INFO - iteration 23, current learner lgbm
# [flaml.automl.logger: 03-21 08:12:14] {2450} INFO -  at 3.1s,	estimator lgbm's best error=0.3113,	best estimator lgbm's best error=0.3113
# [flaml.automl.logger: 03-21 08:12:14] {2272} INFO - iteration 24, current learner lgbm
# [flaml.automl.logger: 03-21 08:12:15] {2450} INFO -  at 3.3s,	estimator lgbm's best error=0.3113,	best estimator lgbm's best error=0.3113
# [flaml.automl.logger: 03-21 08:12:15] {2272} INFO - iteration 25, current learner xgboost
# [flaml.automl.logger: 03-21 08:12:15] {2450} INFO -  at 3.3s,	estimator xgboost's best error=0.3271,	best estimator lgbm's best error=0.3113
# [flaml.automl.logger: 03-21 08:12:15] {2272} INFO - iteration 26, current learner sgd
# [flaml.automl.logger: 03-21 08:12:15] {2450} INFO -  at 3.4s,	estimator sgd's best error=0.3427,	best estimator lgbm's best error=0.3113
# [flaml.automl.logger: 03-21 08:12:15] {2272} INFO - iteration 27, current learner lgbm
# [flaml.automl.logger: 03-21 08:12:15] {2450} INFO -  at 3.5s,	estimator lgbm's best error=0.3113,	best estimator lgbm's best error=0.3113
# [flaml.automl.logger: 03-21 08:12:15] {2272} INFO - iteration 28, current learner xgboost
# [flaml.automl.logger: 03-21 08:12:15] {2450} INFO -  at 3.5s,	estimator xgboost's best error=0.3263,	best estimator lgbm's best error=0.3113
# [flaml.automl.logger: 03-21 08:12:15] {2272} INFO - iteration 29, current learner extra_tree
# [flaml.automl.logger: 03-21 08:12:15] {2450} INFO -  at 3.6s,	estimator extra_tree's best error=0.3433,	best estimator lgbm's best error=0.3113
# [flaml.automl.logger: 03-21 08:12:15] {2272} INFO - iteration 30, current learner extra_tree
# [flaml.automl.logger: 03-21 08:12:15] {2450} INFO -  at 3.7s,	estimator extra_tree's best error=0.3433,	best estimator lgbm's best error=0.3113
# [flaml.automl.logger: 03-21 08:12:15] {2272} INFO - iteration 31, current learner lgbm
# [flaml.automl.logger: 03-21 08:12:15] {2450} INFO -  at 3.9s,	estimator lgbm's best error=0.3113,	best estimator lgbm's best error=0.3113
# [flaml.automl.logger: 03-21 08:12:15] {2272} INFO - iteration 32, current learner lgbm
# [flaml.automl.logger: 03-21 08:12:16] {2450} INFO -  at 4.3s,	estimator lgbm's best error=0.3030,	best estimator lgbm's best error=0.3030
# [flaml.automl.logger: 03-21 08:12:16] {2272} INFO - iteration 33, current learner catboost
# [flaml.automl.logger: 03-21 08:12:17] {2450} INFO -  at 5.4s,	estimator catboost's best error=0.3113,	best estimator lgbm's best error=0.3030
# [flaml.automl.logger: 03-21 08:12:17] {2272} INFO - iteration 34, current learner lgbm
# [flaml.automl.logger: 03-21 08:12:17] {2450} INFO -  at 5.9s,	estimator lgbm's best error=0.2923,	best estimator lgbm's best error=0.2923
# [flaml.automl.logger: 03-21 08:12:17] {2272} INFO - iteration 35, current learner catboost
# [flaml.automl.logger: 03-21 08:12:21] {2450} INFO -  at 9.4s,	estimator catboost's best error=0.3113,	best estimator lgbm's best error=0.2923
# [flaml.automl.logger: 03-21 08:12:21] {2272} INFO - iteration 36, current learner lgbm
# [flaml.automl.logger: 03-21 08:12:21] {2450} INFO -  at 9.8s,	estimator lgbm's best error=0.2923,	best estimator lgbm's best error=0.2923
# [flaml.automl.logger: 03-21 08:12:21] {2272} INFO - iteration 37, current learner lgbm
# [flaml.automl.logger: 03-21 08:12:22] {2450} INFO -  at 10.6s,	estimator lgbm's best error=0.2787,	best estimator lgbm's best error=0.2787
# [flaml.automl.logger: 03-21 08:12:22] {2272} INFO - iteration 38, current learner catboost
# [flaml.automl.logger: 03-21 08:12:22] {2450} INFO -  at 11.0s,	estimator catboost's best error=0.3113,	best estimator lgbm's best error=0.2787
# [flaml.automl.logger: 03-21 08:12:22] {2272} INFO - iteration 39, current learner rf
# [flaml.automl.logger: 03-21 08:12:22] {2450} INFO -  at 11.0s,	estimator rf's best error=0.3267,	best estimator lgbm's best error=0.2787
# [flaml.automl.logger: 03-21 08:12:22] {2272} INFO - iteration 40, current learner extra_tree
# [flaml.automl.logger: 03-21 08:12:22] {2450} INFO -  at 11.1s,	estimator extra_tree's best error=0.3411,	best estimator lgbm's best error=0.2787
# [flaml.automl.logger: 03-21 08:12:22] {2272} INFO - iteration 41, current learner lgbm
# [flaml.automl.logger: 03-21 08:12:23] {2450} INFO -  at 11.6s,	estimator lgbm's best error=0.2787,	best estimator lgbm's best error=0.2787
# [flaml.automl.logger: 03-21 08:12:23] {2272} INFO - iteration 42, current learner extra_tree
# [flaml.automl.logger: 03-21 08:12:23] {2450} INFO -  at 11.8s,	estimator extra_tree's best error=0.3406,	best estimator lgbm's best error=0.2787
# [flaml.automl.logger: 03-21 08:12:23] {2272} INFO - iteration 43, current learner catboost
# [flaml.automl.logger: 03-21 08:12:26] {2450} INFO -  at 15.2s,	estimator catboost's best error=0.3113,	best estimator lgbm's best error=0.2787
# [flaml.automl.logger: 03-21 08:12:26] {2272} INFO - iteration 44, current learner lgbm
# [flaml.automl.logger: 03-21 08:12:27] {2450} INFO -  at 15.4s,	estimator lgbm's best error=0.2787,	best estimator lgbm's best error=0.2787
# [flaml.automl.logger: 03-21 08:12:27] {2272} INFO - iteration 45, current learner sgd
# [flaml.automl.logger: 03-21 08:12:27] {2450} INFO -  at 15.5s,	estimator sgd's best error=0.3416,	best estimator lgbm's best error=0.2787
# [flaml.automl.logger: 03-21 08:12:27] {2272} INFO - iteration 46, current learner catboost
# [flaml.automl.logger: 03-21 08:12:29] {2450} INFO -  at 17.9s,	estimator catboost's best error=0.3043,	best estimator lgbm's best error=0.2787
# [flaml.automl.logger: 03-21 08:12:29] {2272} INFO - iteration 47, current learner xgboost
# [flaml.automl.logger: 03-21 08:12:29] {2450} INFO -  at 17.9s,	estimator xgboost's best error=0.3263,	best estimator lgbm's best error=0.2787
# [flaml.automl.logger: 03-21 08:12:29] {2272} INFO - iteration 48, current learner lgbm
# [flaml.automl.logger: 03-21 08:12:31] {2450} INFO -  at 19.5s,	estimator lgbm's best error=0.2657,	best estimator lgbm's best error=0.2657
# [flaml.automl.logger: 03-21 08:12:31] {2272} INFO - iteration 49, current learner xgboost
# [flaml.automl.logger: 03-21 08:12:31] {2450} INFO -  at 19.5s,	estimator xgboost's best error=0.3192,	best estimator lgbm's best error=0.2657
# [flaml.automl.logger: 03-21 08:12:31] {2272} INFO - iteration 50, current learner lgbm
# [flaml.automl.logger: 03-21 08:12:33] {2450} INFO -  at 21.5s,	estimator lgbm's best error=0.2657,	best estimator lgbm's best error=0.2657
# [flaml.automl.logger: 03-21 08:12:33] {2272} INFO - iteration 51, current learner xgboost
# [flaml.automl.logger: 03-21 08:12:33] {2450} INFO -  at 21.6s,	estimator xgboost's best error=0.3192,	best estimator lgbm's best error=0.2657
# [flaml.automl.logger: 03-21 08:12:33] {2272} INFO - iteration 52, current learner sgd
# [flaml.automl.logger: 03-21 08:12:33] {2450} INFO -  at 21.7s,	estimator sgd's best error=0.3416,	best estimator lgbm's best error=0.2657
# [flaml.automl.logger: 03-21 08:12:33] {2272} INFO - iteration 53, current learner lgbm
# [flaml.automl.logger: 03-21 08:12:35] {2450} INFO -  at 23.9s,	estimator lgbm's best error=0.2657,	best estimator lgbm's best error=0.2657
# [flaml.automl.logger: 03-21 08:12:35] {2272} INFO - iteration 54, current learner lgbm
# [flaml.automl.logger: 03-21 08:12:37] {2450} INFO -  at 25.3s,	estimator lgbm's best error=0.2657,	best estimator lgbm's best error=0.2657
# [flaml.automl.logger: 03-21 08:12:37] {2272} INFO - iteration 55, current learner lgbm
# [flaml.automl.logger: 03-21 08:12:41] {2450} INFO -  at 29.3s,	estimator lgbm's best error=0.2657,	best estimator lgbm's best error=0.2657
# [flaml.automl.logger: 03-21 08:12:41] {2272} INFO - iteration 56, current learner lgbm
# [flaml.automl.logger: 03-21 08:12:46] {2450} INFO -  at 34.4s,	estimator lgbm's best error=0.2575,	best estimator lgbm's best error=0.2575
# [flaml.automl.logger: 03-21 08:12:46] {2272} INFO - iteration 57, current learner xgb_limitdepth
# [flaml.automl.logger: 03-21 08:12:46] {2450} INFO -  at 34.5s,	estimator xgb_limitdepth's best error=0.3145,	best estimator lgbm's best error=0.2575
# [flaml.automl.logger: 03-21 08:12:46] {2272} INFO - iteration 58, current learner xgb_limitdepth
# [flaml.automl.logger: 03-21 08:12:46] {2450} INFO -  at 34.6s,	estimator xgb_limitdepth's best error=0.3145,	best estimator lgbm's best error=0.2575
# [flaml.automl.logger: 03-21 08:12:46] {2272} INFO - iteration 59, current learner xgb_limitdepth
# [flaml.automl.logger: 03-21 08:12:46] {2450} INFO -  at 34.7s,	estimator xgb_limitdepth's best error=0.3145,	best estimator lgbm's best error=0.2575
# [flaml.automl.logger: 03-21 08:12:46] {2272} INFO - iteration 60, current learner xgb_limitdepth
# [flaml.automl.logger: 03-21 08:12:46] {2450} INFO -  at 34.7s,	estimator xgb_limitdepth's best error=0.3145,	best estimator lgbm's best error=0.2575
# [flaml.automl.logger: 03-21 08:12:46] {2272} INFO - iteration 61, current learner xgb_limitdepth
# [flaml.automl.logger: 03-21 08:12:46] {2450} INFO -  at 34.8s,	estimator xgb_limitdepth's best error=0.3145,	best estimator lgbm's best error=0.2575
# [flaml.automl.logger: 03-21 08:12:46] {2272} INFO - iteration 62, current learner xgboost
# [flaml.automl.logger: 03-21 08:12:46] {2450} INFO -  at 34.9s,	estimator xgboost's best error=0.3192,	best estimator lgbm's best error=0.2575
# [flaml.automl.logger: 03-21 08:12:46] {2272} INFO - iteration 63, current learner xgb_limitdepth
# [flaml.automl.logger: 03-21 08:12:46] {2450} INFO -  at 34.9s,	estimator xgb_limitdepth's best error=0.3145,	best estimator lgbm's best error=0.2575
# [flaml.automl.logger: 03-21 08:12:46] {2272} INFO - iteration 64, current learner xgb_limitdepth
# [flaml.automl.logger: 03-21 08:12:46] {2450} INFO -  at 35.1s,	estimator xgb_limitdepth's best error=0.3074,	best estimator lgbm's best error=0.2575
# [flaml.automl.logger: 03-21 08:12:46] {2272} INFO - iteration 65, current learner xgboost
# [flaml.automl.logger: 03-21 08:12:47] {2450} INFO -  at 35.2s,	estimator xgboost's best error=0.3192,	best estimator lgbm's best error=0.2575
# [flaml.automl.logger: 03-21 08:12:47] {2272} INFO - iteration 66, current learner lrl1
# No low-cost partial config given to the search algorithm. For cost-frugal search, consider providing low-cost values for cost-related hps via 'low_cost_partial_config'. More info can be found at https://microsoft.github.io/FLAML/docs/FAQ#about-low_cost_partial_config-in-tune
# [flaml.automl.logger: 03-21 08:12:47] {2450} INFO -  at 35.5s,	estimator lrl1's best error=0.3460,	best estimator lgbm's best error=0.2575
# [flaml.automl.logger: 03-21 08:12:47] {2272} INFO - iteration 67, current learner lrl1
# [flaml.automl.logger: 03-21 08:12:47] {2450} INFO -  at 35.6s,	estimator lrl1's best error=0.3460,	best estimator lgbm's best error=0.2575
# [flaml.automl.logger: 03-21 08:12:47] {2272} INFO - iteration 68, current learner sgd
# [flaml.automl.logger: 03-21 08:12:47] {2450} INFO -  at 35.7s,	estimator sgd's best error=0.3416,	best estimator lgbm's best error=0.2575
# [flaml.automl.logger: 03-21 08:12:47] {2272} INFO - iteration 69, current learner lrl1
# [flaml.automl.logger: 03-21 08:12:47] {2450} INFO -  at 35.8s,	estimator lrl1's best error=0.3460,	best estimator lgbm's best error=0.2575
# [flaml.automl.logger: 03-21 08:12:47] {2272} INFO - iteration 70, current learner lrl1
# [flaml.automl.logger: 03-21 08:12:48] {2450} INFO -  at 36.4s,	estimator lrl1's best error=0.3460,	best estimator lgbm's best error=0.2575
# [flaml.automl.logger: 03-21 08:12:48] {2272} INFO - iteration 71, current learner lrl1
# [flaml.automl.logger: 03-21 08:12:48] {2450} INFO -  at 37.1s,	estimator lrl1's best error=0.3460,	best estimator lgbm's best error=0.2575
# [flaml.automl.logger: 03-21 08:12:48] {2272} INFO - iteration 72, current learner rf
# [flaml.automl.logger: 03-21 08:12:48] {2450} INFO -  at 37.2s,	estimator rf's best error=0.3267,	best estimator lgbm's best error=0.2575
# [flaml.automl.logger: 03-21 08:12:48] {2272} INFO - iteration 73, current learner lrl1
# [flaml.automl.logger: 03-21 08:12:49] {2450} INFO -  at 37.8s,	estimator lrl1's best error=0.3460,	best estimator lgbm's best error=0.2575
# [flaml.automl.logger: 03-21 08:12:49] {2272} INFO - iteration 74, current learner lrl1
# [flaml.automl.logger: 03-21 08:12:56] {2450} INFO -  at 44.9s,	estimator lrl1's best error=0.3449,	best estimator lgbm's best error=0.2575
# [flaml.automl.logger: 03-21 08:12:56] {2272} INFO - iteration 75, current learner extra_tree
# [flaml.automl.logger: 03-21 08:12:56] {2450} INFO -  at 44.9s,	estimator extra_tree's best error=0.3406,	best estimator lgbm's best error=0.2575
# [flaml.automl.logger: 03-21 08:12:56] {2272} INFO - iteration 76, current learner sgd
# [flaml.automl.logger: 03-21 08:12:56] {2450} INFO -  at 44.9s,	estimator sgd's best error=0.3416,	best estimator lgbm's best error=0.2575
# [flaml.automl.logger: 03-21 08:12:56] {2272} INFO - iteration 77, current learner xgb_limitdepth
# [flaml.automl.logger: 03-21 08:12:56] {2450} INFO -  at 45.1s,	estimator xgb_limitdepth's best error=0.3074,	best estimator lgbm's best error=0.2575
# [flaml.automl.logger: 03-21 08:12:56] {2272} INFO - iteration 78, current learner sgd
# [flaml.automl.logger: 03-21 08:12:57] {2450} INFO -  at 45.3s,	estimator sgd's best error=0.3416,	best estimator lgbm's best error=0.2575
# [flaml.automl.logger: 03-21 08:12:57] {2272} INFO - iteration 79, current learner lgbm
# [flaml.automl.logger: 03-21 08:12:59] {2450} INFO -  at 47.2s,	estimator lgbm's best error=0.2575,	best estimator lgbm's best error=0.2575
# [flaml.automl.logger: 03-21 08:12:59] {2272} INFO - iteration 80, current learner lgbm
# [flaml.automl.logger: 03-21 08:13:24] {2450} INFO -  at 72.4s,	estimator lgbm's best error=0.2575,	best estimator lgbm's best error=0.2575
# [flaml.automl.logger: 03-21 08:13:24] {2272} INFO - iteration 81, current learner xgb_limitdepth
# [flaml.automl.logger: 03-21 08:13:24] {2450} INFO -  at 72.6s,	estimator xgb_limitdepth's best error=0.3074,	best estimator lgbm's best error=0.2575
# [flaml.automl.logger: 03-21 08:13:24] {2272} INFO - iteration 82, current learner xgboost
# [flaml.automl.logger: 03-21 08:13:24] {2450} INFO -  at 72.7s,	estimator xgboost's best error=0.3153,	best estimator lgbm's best error=0.2575
# [flaml.automl.logger: 03-21 08:13:24] {2272} INFO - iteration 83, current learner rf
# [flaml.automl.logger: 03-21 08:13:24] {2450} INFO -  at 72.9s,	estimator rf's best error=0.3227,	best estimator lgbm's best error=0.2575
# [flaml.automl.logger: 03-21 08:13:24] {2272} INFO - iteration 84, current learner sgd
# [flaml.automl.logger: 03-21 08:13:24] {2450} INFO -  at 72.9s,	estimator sgd's best error=0.3416,	best estimator lgbm's best error=0.2575
# [flaml.automl.logger: 03-21 08:13:24] {2272} INFO - iteration 85, current learner rf
# [flaml.automl.logger: 03-21 08:13:24] {2450} INFO -  at 73.1s,	estimator rf's best error=0.3196,	best estimator lgbm's best error=0.2575
# [flaml.automl.logger: 03-21 08:13:24] {2272} INFO - iteration 86, current learner xgb_limitdepth
# [flaml.automl.logger: 03-21 08:13:24] {2450} INFO -  at 73.2s,	estimator xgb_limitdepth's best error=0.3036,	best estimator lgbm's best error=0.2575
# [flaml.automl.logger: 03-21 08:13:24] {2272} INFO - iteration 87, current learner xgb_limitdepth
# [flaml.automl.logger: 03-21 08:13:25] {2450} INFO -  at 73.3s,	estimator xgb_limitdepth's best error=0.3036,	best estimator lgbm's best error=0.2575
# [flaml.automl.logger: 03-21 08:13:25] {2272} INFO - iteration 88, current learner xgb_limitdepth
# [flaml.automl.logger: 03-21 08:13:25] {2450} INFO -  at 73.4s,	estimator xgb_limitdepth's best error=0.3036,	best estimator lgbm's best error=0.2575
# [flaml.automl.logger: 03-21 08:13:25] {2272} INFO - iteration 89, current learner xgboost
# [flaml.automl.logger: 03-21 08:13:25] {2450} INFO -  at 73.5s,	estimator xgboost's best error=0.3153,	best estimator lgbm's best error=0.2575
# [flaml.automl.logger: 03-21 08:13:25] {2272} INFO - iteration 90, current learner extra_tree
# [flaml.automl.logger: 03-21 08:13:25] {2450} INFO -  at 73.7s,	estimator extra_tree's best error=0.3362,	best estimator lgbm's best error=0.2575
# [flaml.automl.logger: 03-21 08:13:25] {2272} INFO - iteration 91, current learner rf
# [flaml.automl.logger: 03-21 08:13:25] {2450} INFO -  at 73.7s,	estimator rf's best error=0.3196,	best estimator lgbm's best error=0.2575
# [flaml.automl.logger: 03-21 08:13:25] {2272} INFO - iteration 92, current learner rf
# [flaml.automl.logger: 03-21 08:13:25] {2450} INFO -  at 73.9s,	estimator rf's best error=0.3196,	best estimator lgbm's best error=0.2575
# [flaml.automl.logger: 03-21 08:13:25] {2272} INFO - iteration 93, current learner xgb_limitdepth
# [flaml.automl.logger: 03-21 08:13:25] {2450} INFO -  at 74.2s,	estimator xgb_limitdepth's best error=0.3029,	best estimator lgbm's best error=0.2575
# [flaml.automl.logger: 03-21 08:13:25] {2272} INFO - iteration 94, current learner xgboost
# [flaml.automl.logger: 03-21 08:13:26] {2450} INFO -  at 74.2s,	estimator xgboost's best error=0.3132,	best estimator lgbm's best error=0.2575
# [flaml.automl.logger: 03-21 08:13:26] {2272} INFO - iteration 95, current learner sgd
# [flaml.automl.logger: 03-21 08:13:26] {2450} INFO -  at 74.3s,	estimator sgd's best error=0.3416,	best estimator lgbm's best error=0.2575
# [flaml.automl.logger: 03-21 08:13:26] {2272} INFO - iteration 96, current learner extra_tree
# [flaml.automl.logger: 03-21 08:13:26] {2450} INFO -  at 74.5s,	estimator extra_tree's best error=0.3362,	best estimator lgbm's best error=0.2575
# [flaml.automl.logger: 03-21 08:13:26] {2272} INFO - iteration 97, current learner xgboost
# [flaml.automl.logger: 03-21 08:13:26] {2450} INFO -  at 74.6s,	estimator xgboost's best error=0.3118,	best estimator lgbm's best error=0.2575
# [flaml.automl.logger: 03-21 08:13:26] {2272} INFO - iteration 98, current learner rf
# [flaml.automl.logger: 03-21 08:13:26] {2450} INFO -  at 74.8s,	estimator rf's best error=0.3196,	best estimator lgbm's best error=0.2575
# [flaml.automl.logger: 03-21 08:13:26] {2272} INFO - iteration 99, current learner sgd
# [flaml.automl.logger: 03-21 08:13:26] {2450} INFO -  at 75.1s,	estimator sgd's best error=0.3416,	best estimator lgbm's best error=0.2575
# [flaml.automl.logger: 03-21 08:13:26] {2272} INFO - iteration 100, current learner xgboost
# [flaml.automl.logger: 03-21 08:13:27] {2450} INFO -  at 75.2s,	estimator xgboost's best error=0.3118,	best estimator lgbm's best error=0.2575
# [flaml.automl.logger: 03-21 08:13:27] {2272} INFO - iteration 101, current learner xgboost
# [flaml.automl.logger: 03-21 08:13:27] {2450} INFO -  at 75.3s,	estimator xgboost's best error=0.3118,	best estimator lgbm's best error=0.2575
# [flaml.automl.logger: 03-21 08:13:27] {2272} INFO - iteration 102, current learner xgboost
# [flaml.automl.logger: 03-21 08:13:27] {2450} INFO -  at 75.5s,	estimator xgboost's best error=0.3118,	best estimator lgbm's best error=0.2575
# [flaml.automl.logger: 03-21 08:13:27] {2272} INFO - iteration 103, current learner rf
# [flaml.automl.logger: 03-21 08:13:27] {2450} INFO -  at 75.7s,	estimator rf's best error=0.3196,	best estimator lgbm's best error=0.2575
# [flaml.automl.logger: 03-21 08:13:27] {2272} INFO - iteration 104, current learner xgb_limitdepth
# [flaml.automl.logger: 03-21 08:13:27] {2450} INFO -  at 75.8s,	estimator xgb_limitdepth's best error=0.3029,	best estimator lgbm's best error=0.2575
# [flaml.automl.logger: 03-21 08:13:27] {2272} INFO - iteration 105, current learner extra_tree
# [flaml.automl.logger: 03-21 08:13:27] {2450} INFO -  at 76.1s,	estimator extra_tree's best error=0.3362,	best estimator lgbm's best error=0.2575
# [flaml.automl.logger: 03-21 08:13:27] {2272} INFO - iteration 106, current learner lgbm
# [flaml.automl.logger: 03-21 08:13:29] {2450} INFO -  at 77.4s,	estimator lgbm's best error=0.2575,	best estimator lgbm's best error=0.2575
# [flaml.automl.logger: 03-21 08:13:29] {2272} INFO - iteration 107, current learner extra_tree
# [flaml.automl.logger: 03-21 08:13:29] {2450} INFO -  at 77.6s,	estimator extra_tree's best error=0.3362,	best estimator lgbm's best error=0.2575
# [flaml.automl.logger: 03-21 08:13:29] {2272} INFO - iteration 108, current learner rf
# [flaml.automl.logger: 03-21 08:13:29] {2450} INFO -  at 77.9s,	estimator rf's best error=0.3137,	best estimator lgbm's best error=0.2575
# [flaml.automl.logger: 03-21 08:13:29] {2272} INFO - iteration 109, current learner xgboost
# [flaml.automl.logger: 03-21 08:13:29] {2450} INFO -  at 78.1s,	estimator xgboost's best error=0.3094,	best estimator lgbm's best error=0.2575
# [flaml.automl.logger: 03-21 08:13:29] {2272} INFO - iteration 110, current learner xgb_limitdepth
# [flaml.automl.logger: 03-21 08:13:30] {2450} INFO -  at 78.8s,	estimator xgb_limitdepth's best error=0.3023,	best estimator lgbm's best error=0.2575
# [flaml.automl.logger: 03-21 08:13:30] {2272} INFO - iteration 111, current learner rf
# [flaml.automl.logger: 03-21 08:13:30] {2450} INFO -  at 79.0s,	estimator rf's best error=0.3130,	best estimator lgbm's best error=0.2575
# [flaml.automl.logger: 03-21 08:13:30] {2272} INFO - iteration 112, current learner sgd
# [flaml.automl.logger: 03-21 08:13:31] {2450} INFO -  at 79.3s,	estimator sgd's best error=0.3416,	best estimator lgbm's best error=0.2575
# [flaml.automl.logger: 03-21 08:13:31] {2272} INFO - iteration 113, current learner xgboost
# [flaml.automl.logger: 03-21 08:13:31] {2450} INFO -  at 79.5s,	estimator xgboost's best error=0.3094,	best estimator lgbm's best error=0.2575
# [flaml.automl.logger: 03-21 08:13:31] {2272} INFO - iteration 114, current learner lgbm
# [flaml.automl.logger: 03-21 08:13:32] {2450} INFO -  at 80.7s,	estimator lgbm's best error=0.2575,	best estimator lgbm's best error=0.2575
# [flaml.automl.logger: 03-21 08:13:32] {2272} INFO - iteration 115, current learner sgd
# [flaml.automl.logger: 03-21 08:13:35] {2450} INFO -  at 83.4s,	estimator sgd's best error=0.3416,	best estimator lgbm's best error=0.2575
# [flaml.automl.logger: 03-21 08:13:35] {2272} INFO - iteration 116, current learner extra_tree
# [flaml.automl.logger: 03-21 08:13:35] {2450} INFO -  at 83.5s,	estimator extra_tree's best error=0.3362,	best estimator lgbm's best error=0.2575
# [flaml.automl.logger: 03-21 08:13:35] {2272} INFO - iteration 117, current learner lrl1
# [flaml.automl.logger: 03-21 08:13:41] {2450} INFO -  at 90.2s,	estimator lrl1's best error=0.3448,	best estimator lgbm's best error=0.2575
# [flaml.automl.logger: 03-21 08:13:41] {2272} INFO - iteration 118, current learner lgbm
# [flaml.automl.logger: 03-21 08:14:05] {2450} INFO -  at 113.7s,	estimator lgbm's best error=0.2570,	best estimator lgbm's best error=0.2570
# [flaml.automl.logger: 03-21 08:14:05] {2272} INFO - iteration 119, current learner lgbm
# [flaml.automl.logger: 03-21 08:14:29] {2450} INFO -  at 137.7s,	estimator lgbm's best error=0.2570,	best estimator lgbm's best error=0.2570
# [flaml.automl.logger: 03-21 08:14:29] {2272} INFO - iteration 120, current learner sgd
# [flaml.automl.logger: 03-21 08:14:34] {2450} INFO -  at 142.4s,	estimator sgd's best error=0.3416,	best estimator lgbm's best error=0.2570
# [flaml.automl.logger: 03-21 08:14:34] {2272} INFO - iteration 121, current learner extra_tree
# [flaml.automl.logger: 03-21 08:14:34] {2450} INFO -  at 142.5s,	estimator extra_tree's best error=0.3328,	best estimator lgbm's best error=0.2570
# [flaml.automl.logger: 03-21 08:14:34] {2272} INFO - iteration 122, current learner lgbm
# [flaml.automl.logger: 03-21 08:15:08] {2450} INFO -  at 176.6s,	estimator lgbm's best error=0.2518,	best estimator lgbm's best error=0.2518
# [flaml.automl.logger: 03-21 08:15:08] {2272} INFO - iteration 123, current learner extra_tree
# [flaml.automl.logger: 03-21 08:15:08] {2450} INFO -  at 176.7s,	estimator extra_tree's best error=0.3328,	best estimator lgbm's best error=0.2518
# [flaml.automl.logger: 03-21 08:15:08] {2272} INFO - iteration 124, current learner extra_tree
# [flaml.automl.logger: 03-21 08:15:08] {2450} INFO -  at 176.9s,	estimator extra_tree's best error=0.3328,	best estimator lgbm's best error=0.2518
# [flaml.automl.logger: 03-21 08:15:08] {2272} INFO - iteration 125, current learner xgb_limitdepth
# [flaml.automl.logger: 03-21 08:15:09] {2450} INFO -  at 177.3s,	estimator xgb_limitdepth's best error=0.3023,	best estimator lgbm's best error=0.2518
# [flaml.automl.logger: 03-21 08:15:09] {2272} INFO - iteration 126, current learner extra_tree
# [flaml.automl.logger: 03-21 08:15:09] {2450} INFO -  at 177.6s,	estimator extra_tree's best error=0.3241,	best estimator lgbm's best error=0.2518
# [flaml.automl.logger: 03-21 08:15:09] {2272} INFO - iteration 127, current learner rf
# [flaml.automl.logger: 03-21 08:15:09] {2450} INFO -  at 177.8s,	estimator rf's best error=0.3129,	best estimator lgbm's best error=0.2518
# [flaml.automl.logger: 03-21 08:15:09] {2272} INFO - iteration 128, current learner lgbm
# [flaml.automl.logger: 03-21 08:16:04] {2450} INFO -  at 232.4s,	estimator lgbm's best error=0.2328,	best estimator lgbm's best error=0.2328
# [flaml.automl.logger: 03-21 08:16:04] {2272} INFO - iteration 129, current learner lgbm
# [flaml.automl.logger: 03-21 08:16:41] {2450} INFO -  at 269.3s,	estimator lgbm's best error=0.2328,	best estimator lgbm's best error=0.2328
# [flaml.automl.logger: 03-21 08:16:41] {2272} INFO - iteration 130, current learner lgbm
# [flaml.automl.logger: 03-21 08:20:35] {2450} INFO -  at 503.3s,	estimator lgbm's best error=0.2328,	best estimator lgbm's best error=0.2328
# [flaml.automl.logger: 03-21 08:21:24] {2693} INFO - retrain lgbm for 49.1s
# [flaml.automl.logger: 03-21 08:21:24] {2696} INFO - retrained model: LGBMClassifier(colsample_bytree=0.9429529415401117,
#                learning_rate=0.17149110323428812, max_bin=255,
#                min_child_samples=3, n_estimators=1, n_jobs=-1, num_leaves=4032,
#                reg_alpha=0.06148057774142418, reg_lambda=0.10402728169360116,
#                verbose=-1)
# [flaml.automl.logger: 03-21 08:21:24] {2697} INFO - Auto Feature Engineering pipeline: None
# [flaml.automl.logger: 03-21 08:21:24] {2699} INFO - Best MLflow run name:
# [flaml.automl.logger: 03-21 08:21:24] {2700} INFO - Best MLflow run id: 8fd4103e-db3c-43ee-a60f-72cbf1c4dd06
# [flaml.automl.logger: 03-21 08:21:24] {2007} INFO - fit succeeded
# [flaml.automl.logger: 03-21 08:21:24] {2008} INFO - Time taken to find the best model: 232.43521189689636

# %%
print(automl.model.estimator)
# Out:
# StatementMeta(, 4797ad00-b78c-4ff3-9bf9-e026ac033a53, 31, Finished, Available)
# LGBMClassifier(colsample_bytree=0.9429529415401117,
#                learning_rate=0.17149110323428812, max_bin=255,
#                min_child_samples=3, n_estimators=1, n_jobs=-1, num_leaves=4032,
#                reg_alpha=0.06148057774142418, reg_lambda=0.10402728169360116,
#                verbose=-1)

# %%
testPandas = test.toPandas()
prediction_arr = automl.predict(testPandas[featureslist])
predictions = testPandas
predictions['prediction'] = prediction_arr
display(predictions)
# Out:
# StatementMeta(, 4797ad00-b78c-4ff3-9bf9-e026ac033a53, 32, Finished, Available)
# SynapseWidget(Synapse.DataFrame, 06c0db12-da57-4fcc-9bea-abecdf62a1a0)

# %%
y_true = predictions['DelayType']
y_pred = predictions['prediction']
print(classification_report(y_true, y_pred))
print(confusion_matrix(y_true,y_pred))
# Out:
# StatementMeta(, 4797ad00-b78c-4ff3-9bf9-e026ac033a53, 33, Finished, Available)
#               precision    recall  f1-score   support
#
#            0       0.79      0.89      0.84     95811
#            1       0.72      0.53      0.61     49672
#
#     accuracy                           0.77    145483
#    macro avg       0.75      0.71      0.73    145483
# weighted avg       0.77      0.77      0.76    145483
#
# [[85608 10203]
#  [23131 26541]]

# %%
(85608 + 26541) / ( 26541 + 23131 + 10203 + 85608 )
# Out:
# StatementMeta(, 4797ad00-b78c-4ff3-9bf9-e026ac033a53, 35, Finished, Available)
# 0.7708735728573098
